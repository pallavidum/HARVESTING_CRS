# %%
import pandas as pd
import numpy as np
from CreditRisk import CreditRisk
from UnivariateAnalysis import UnivariateAnalysis
from LogisticRegression import LogisticRegression
from RandomForest import RandomForest
import re

# %%
DATA = "combined_data_all_numerical.csv"
df = pd.read_csv(DATA, delimiter='\t')
df.head()
# Out:
#    limit bal  sex  education  marriage  age  irrigation pay status  \
# 0      50000    1          3         2   28                      2
# 1     200000    1          2         1   38                      0
# 2      50000    1          3         2   43                     -1
# 3     140000    2          2         2   30                     -1
# 4      20000    2          1         2   22                      0
#
#    electricity bill pay status  land rent pay status  \
# 0                            2                     2
# 1                            0                     0
# 2                           -1                    -1
# 3                           -1                    -2
# 4                            0                     2
#
#    children school fee pay status  equipment rent pay status  \
# 0                               0                          0
# 1                               0                          0
# ...

# %%
#print(df.dtypes)

# %%
CR = CreditRisk("", "")
df_processed, classes = CR.read_file(df, "")
#df_processed.head()

# %%
#%time rand_forest = RandomForest("", 0.8, 0.95).run()
#%time rand_forest = RandomForest("", 0.8, 0.9).run()
# %time rand_forest = RandomForest("", 0.8, 0.85).run()
#%time rand_forest = RandomForest("", 0.8, 0.80).run()
#%time rand_forest = RandomForest("", 0.8, 0.75).run()
# Out:
# random forest accuracy: 0.7905
# CPU times: user 1min 47s, sys: 635 ms, total: 1min 47s
# Wall time: 1min 48s

# %%
#%time model = LogisticRegression("", 0.8).run()
#print(model)
